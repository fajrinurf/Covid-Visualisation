# %%
import pandas as pd   #library pandas
import matplotlib .pyplot as plt

# %%
ar = pd.read_csv("covid.csv") #membaca data

# %%
print("Jumlah data keseluruhan : ", len(ar)) #menghitung banyaknya data
# Out:
# Jumlah data keseluruhan :  27138

# %%
ar.tail()
# Out:
#              Date      Country/Region  Confirmed  Deaths  Recovered  Active  \
# 27133  2020-07-27  West Bank and Gaza      10621      78       3752    6791
# 27134  2020-07-27      Western Sahara         10       1          8       1
# 27135  2020-07-27               Yemen       1691     483        833     375
# 27136  2020-07-27              Zambia       4552     140       2815    1597
# 27137  2020-07-27            Zimbabwe       2704      36        542    2126
#
#        New cases  New deaths  New recovered             WHO Region
# 27133        152           2              0  Eastern Mediterranean
# 27134          0           0              0                 Africa
# 27135         10           4             36  Eastern Mediterranean
# 27136         71           1            465                 Africa
# 27137        192           2             24                 Africa

# %%
ar[200:205]
# Out:
#            Date Country/Region  Confirmed  Deaths  Recovered  Active  \
# 200  2020-02-03          Japan         20       0          1      19
# 201  2020-02-03       Malaysia          8       0          0       8
# 202  2020-02-03          Nepal          1       0          0       1
# 203  2020-02-03    Philippines          2       1          0       1
# 204  2020-02-03         Russia          2       0          0       2
#
#      New cases  New deaths  New recovered       WHO Region
# 200          0           0              0  Western Pacific
# 201          0           0              0  Western Pacific
# 202          0           0              0  South-East Asia
# 203          0           0              0  Western Pacific
# 204          0           0              0           Europe

# %%
ar["WHO Region"].value_counts()
# Out:
# Europe                   8445
# Africa                   6269
# Americas                 4941
# Eastern Mediterranean    3243
# Western Pacific          2677
# South-East Asia          1563
# Name: WHO Region, dtype: int64

# %%
ar["Deaths"].corr(ar["Recovered"])
# Out:
# 0.7590739072277009

# %%
ar.loc[ar['Date']=='2020-06-03'].loc[ar['Country/Region']=='Indonesia']
# Out:
#              Date Country/Region  Confirmed  Deaths  Recovered  Active  \
# 16933  2020-06-03      Indonesia      28233    1698       8406   18129
#
#        New cases  New deaths  New recovered       WHO Region
# 16933        684          35            471  South-East Asia

# %%
ar.loc[(ar['Country/Region']=='Indonesia') | (ar['Country/Region']=='Singapore')]
# Out:
#              Date Country/Region  Confirmed  Deaths  Recovered  Active  \
# 8      2020-01-23      Singapore          1       0          0       1
# 17     2020-01-24      Singapore          3       0          0       3
# 28     2020-01-25      Singapore          3       0          0       3
# 41     2020-01-26      Singapore          4       0          0       4
# 56     2020-01-27      Singapore          5       0          0       5
# ...           ...            ...        ...     ...        ...     ...
# 26727  2020-07-25      Singapore      49888      27      45352    4509
# 26844  2020-07-26      Indonesia      98778    4781      56655   37342
# 26914  2020-07-26      Singapore      50369      27      45521    4821
# 27031  2020-07-27      Indonesia     100303    4838      58173   37292
# 27101  2020-07-27      Singapore      50838      27      45692    5119
#
#        New cases  New deaths  New recovered       WHO Region
# ...

# %%
ar.loc[ar['Country/Region']=='Indonesia']
# Out:
#              Date Country/Region  Confirmed  Deaths  Recovered  Active  \
# 1146   2020-03-02      Indonesia          2       0          0       2
# 1220   2020-03-03      Indonesia          2       0          0       2
# 1297   2020-03-04      Indonesia          2       0          0       2
# 1378   2020-03-05      Indonesia          2       0          0       2
# 1467   2020-03-06      Indonesia          4       0          0       4
# ...           ...            ...        ...     ...        ...     ...
# 26283  2020-07-23      Indonesia      93657    4576      52164   36917
# 26470  2020-07-24      Indonesia      95418    4665      53945   36808
# 26657  2020-07-25      Indonesia      97286    4714      55354   37218
# 26844  2020-07-26      Indonesia      98778    4781      56655   37342
# 27031  2020-07-27      Indonesia     100303    4838      58173   37292
#
#        New cases  New deaths  New recovered       WHO Region
# ...

# %%
ar.loc[ar['Country/Region']=='Singapore']
# Out:
#              Date Country/Region  Confirmed  Deaths  Recovered  Active  \
# 8      2020-01-23      Singapore          1       0          0       1
# 17     2020-01-24      Singapore          3       0          0       3
# 28     2020-01-25      Singapore          3       0          0       3
# 41     2020-01-26      Singapore          4       0          0       4
# 56     2020-01-27      Singapore          5       0          0       5
# ...           ...            ...        ...     ...        ...     ...
# 26353  2020-07-23      Singapore      49098      27      45015    4056
# 26540  2020-07-24      Singapore      49375      27      45172    4176
# 26727  2020-07-25      Singapore      49888      27      45352    4509
# 26914  2020-07-26      Singapore      50369      27      45521    4821
# 27101  2020-07-27      Singapore      50838      27      45692    5119
#
#        New cases  New deaths  New recovered       WHO Region
# ...

# %%
len(ar.loc[ar["Confirmed"] < 100000].loc[ar["Date"]=='2020-07-27'])
# Out:
# 163

# %%
ar.loc[ar['Country/Region']=='Indonesia'][:1]
# Out:
#             Date Country/Region  Confirmed  Deaths  Recovered  Active  \
# 1146  2020-03-02      Indonesia          2       0          0       2
#
#       New cases  New deaths  New recovered       WHO Region
# 1146          2           0              0  South-East Asia

# %%
ar1=ar.loc[ar['Country/Region']=='China']
max_Active = ar1['Active'].max()
ar1.loc[ar1['Active']==max_Active]
# Out:
#            Date Country/Region  Confirmed  Deaths  Recovered  Active  \
# 561  2020-02-17          China      72434    1864      11831   58739
#
#      New cases  New deaths  New recovered       WHO Region
# 561       1921          98           1621  Western Pacific

# %%
ar1=ar.loc[ar['Country/Region']=='China']
max_Active = ar1['Active'].max()
ar1.loc[ar1['Active']==max_Active]
# Out:
#            Date Country/Region  Confirmed  Deaths  Recovered  Active  \
# 561  2020-02-17          China      72434    1864      11831   58739
#
#      New cases  New deaths  New recovered       WHO Region
# 561       1921          98           1621  Western Pacific

# %%
target_ar=ar['Country/Region']=='China'
target_ar.value_counts().plot(kind="line",x="Confirmed",y="China",title="Jumlah data Terkonfirmasi di China")

# %%
target_ar1=ar.loc[ar['Country/Region']=='Indonesia']
target_ar1.plot(kind="scatter", x="Confirmed", y="New cases", color="blue")

# %%
target_ar1=ar['Country/Region']
target_ar1.value_counts().plot(kind="line",x="Confirmed",y=["Indonesia","Italy","China","India"])
